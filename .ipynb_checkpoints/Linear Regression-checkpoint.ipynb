# %%
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
plt.rc("figure", figsize=(12,6))

# %%
X, y, coef = make_regression(n_samples=1000, n_features=10, coef=True)
coef
# Out:
# array([55.47644326, 20.87631363, 88.56475733, 24.54491296, 28.41905387,
#        72.81076714, 70.29453394, 54.44348923,  3.21240096, 59.56134143])

# %%
plt.plot(y);

# %% [markdown]
# ## Vanilla Python

# %%
def py_dot_product(vec1, vec2):
    size = len(vec1)
    result = [0] * size
    for i in range(size):
        result[i] = vec1[i] * vec2[i]
    return sum(result)
    
def py_forward(w, X):
    size = len(X)
    predict = [0] * size
    for i in range(size):
        predict[i] = py_dot_product(X[i], w)
    return predict

def py_loss(predict, y):
    size = len(y)
    result = 0
    for i in range(size):
        sq = (predict[i] - y[i]) ** 2
        result += sq
    return result / (2*size)

def py_grad(predict, X, y):
    size = len(y)
    column_size = len(X[0])
    grad = [0] * column_size
    for i in range(size):
        vals = [0] * column_size
        for j in range(column_size):
            grad[j] += (predict[i] - y[i]) * X[i][j]
    return grad
            
def py_update_params(w, grad, lr):
    return [w[i] - lr * grad[i] for i in range(len(w))]

# %%
## Does not work
# X_temp = X.tolist()
# py_X = [[1] * 11] * 1000
# for i in range(len(py_X)):
#     py_X[i][1:] = X_temp[i]

# %%
py_X = np.insert(X, 0, 1, axis=1).tolist()
py_y = y.tolist()
py_w = [0]*len(py_X[0])

# %%
n_iter = 100
history = [0] * n_iter
for i in range(n_iter):
    pred = py_forward(py_w, py_X)

    loss = py_loss(pred, py_y)
    history[i] = loss 
    
    grad = py_grad(pred, py_X, py_y)

    py_w = py_update_params(py_w, grad, 0.0001)

# %%
plt.plot(history);

# %%
plt.plot(pred)
plt.plot(py_y)
plt.legend(["Predict", "Real"])
plt.show()

# %%
np.array(py_w[1:])
# Out:
# array([55.4794    , 20.87014888, 88.55697036, 24.54585276, 28.40951662,
#        72.80171623, 70.29180227, 54.44006508,  3.21371137, 59.55834397])

# %%
coef
# Out:
# array([55.47644326, 20.87631363, 88.56475733, 24.54491296, 28.41905387,
#        72.81076714, 70.29453394, 54.44348923,  3.21240096, 59.56134143])

# %% [markdown]
# ## Numpy

# %%
def np_forward(w, X):
    return X.dot(w)

def np_loss(predict, y):
    return np.mean((predict - y)**2) / 2

def np_grad(predict, X, y):
    column_size = X.shape[1]
    grad = np.empty(column_size)
    for i in range(column_size):
        grad[i] = np.sum((predict - y) * X[:, i])
    return grad

# Pass by reference
def np_update_params(w, grad, lr):
    w -= lr * grad

# %%
np_X = np.insert(X, 0, 1, axis=1)
np_y = y
np_w = np.zeros(np_X.shape[1])

# %%
n_iter = 10
history = np.empty(n_iter)
for i in range(n_iter):
    pred = np_forward(np_w, np_X)
    loss = np_loss(pred, np_y)
    history[i] = loss
    grad = np_grad(pred, np_X, np_y)
    np_update_params(np_w, grad, 0.001)

# %%
np_w[1:]
# Out:
# array([55.4764441 , 20.87631308, 88.56475616, 24.54491328, 28.41905267,
#        72.81076556, 70.29453396, 54.44348866,  3.21240115, 59.56134068])

# %%
coef
# Out:
# array([55.47644326, 20.87631363, 88.56475733, 24.54491296, 28.41905387,
#        72.81076714, 70.29453394, 54.44348923,  3.21240096, 59.56134143])

# %%
plt.plot(history);

# %%
plt.plot(pred)
plt.plot(np_y)
plt.legend(["Predict", "Real"])
plt.show()
