# %%
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
plt.rc("figure", figsize=(12,6))

# %%
X, y, coef = make_regression(n_samples=1000, n_features=10, coef=True)
coef
# Out:
# array([35.08755866, 84.64561755, 91.32015113, 91.69488078, 26.90404212,
#        22.45505084, 43.7931341 ,  1.86505838, 23.23026354, 64.99217604])

# %%
plt.plot(y);

# %% [markdown]
# ## Vanilla Python

# %%
def py_dot_product(vec1, vec2):
    size = len(vec1)
    result = [0] * size
    for i in range(size):
        result[i] = vec1[i] * vec2[i]
    return sum(result)
    
def py_forward(w, X):
    size = len(X)
    predict = [0] * size
    for i in range(size):
        predict[i] = py_dot_product(X[i], w)
    return predict

def py_loss(predict, y):
    size = len(y)
    result = 0
    for i in range(size):
        sq = (predict[i] - y[i]) ** 2
        result += sq
    return result / (2*size)

def py_grad(predict, X, y):
    size = len(y)
    column_size = len(X[0])
    grad = [0] * column_size
    for i in range(size):
        vals = [0] * column_size
        for j in range(column_size):
            grad[j] += (predict[i] - y[i]) * X[i][j]
    return grad
            
def py_update_params(w, grad, lr):
    return [w[i] - lr * grad[i] for i in range(len(w))]

# %%
## Does not work
# X_temp = X.tolist()
# py_X = [[1] * 11] * 1000
# for i in range(len(py_X)):
#     py_X[i][1:] = X_temp[i]

# %%
py_X = np.insert(X, 0, 1, axis=1).tolist()
py_y = y.tolist()
py_w = [0]*len(py_X[0])

# %%
n_iter = 100
history = [0] * n_iter
for i in range(n_iter):
    pred = py_forward(py_w, py_X)

    history[i] = py_loss(pred, py_y)
    
    grad = py_grad(pred, py_X, py_y)

    py_w = py_update_params(py_w, grad, 0.0001)

# %%
plt.plot(history);

# %%
plt.plot(pred)
plt.plot(py_y)
plt.legend(["Predict", "Real"])
plt.show()

# %%
np.array(py_w[1:])
# Out:
# array([35.08575624, 84.64315828, 91.31586395, 91.69415053, 26.90120658,
#        22.45532024, 43.79070466,  1.86554826, 23.23058828, 64.99016636])

# %%
coef
# Out:
# array([35.08755866, 84.64561755, 91.32015113, 91.69488078, 26.90404212,
#        22.45505084, 43.7931341 ,  1.86505838, 23.23026354, 64.99217604])

# %% [markdown]
# ## Numpy

# %%
def np_forward(w, X):
    return X.dot(w)

def np_loss(predict, y):
    return np.mean((predict - y)**2) / 2

def np_grad(predict, X, y):
    column_size = X.shape[1]
    grad = np.empty(column_size)
    for i in range(column_size):
        grad[i] = np.sum((predict - y) * X[:, i])
    return grad

# Pass by reference
def np_update_params(w, grad, lr):
    w -= lr * grad

# %%
np_X = np.insert(X, 0, 1, axis=1)
np_y = y
np_w = np.zeros(np_X.shape[1])

# %%
pred = np_forward(np_w, np_X)
np_grad(pred, np_X, np_y)
# Out:
# array([  -5629.46479234,  -33024.7359866 ,  -84299.53790629,
#         -90046.03838162, -100185.11520676,  -21582.25037292,
#         -28282.6465875 ,  -39316.26133257,   -1010.62219963,
#         -25992.90987561,  -65711.06690511])

# %%
n_iter = 10
history = np.empty(n_iter)
for i in range(n_iter):
    pred = np_forward(np_w, np_X)
    
    history[i] = np_loss(pred, np_y)
    
    grad = np_grad(pred, np_X, np_y)
    
    np_update_params(np_w, grad, 0.001)

# %%
np_w[1:]
# Out:
# array([35.08755846, 84.64561907, 91.32015052, 91.69487962, 26.90404211,
#        22.45505053, 43.7931344 ,  1.86505913, 23.2302632 , 64.99217525])

# %%
coef
# Out:
# array([35.08755866, 84.64561755, 91.32015113, 91.69488078, 26.90404212,
#        22.45505084, 43.7931341 ,  1.86505838, 23.23026354, 64.99217604])

# %%
plt.plot(history);

# %%
plt.plot(pred)
plt.plot(np_y)
plt.legend(["Predict", "Real"])
plt.show()

# %% [markdown]
# ## Jax

# %%
import jax
from jax import jit
from jax import grad as jgrad
from jax import numpy as jnp

# Setting device to cpu
jax.config.update('jax_platform_name', 'cpu')

# %%
@jit
def jax_forward(w, X):
    return X.dot(w)

@jit
def jax_loss(w, X, y):
    predict = jax_forward(w, X)
    return jnp.mean(jnp.square(predict - y)) / jnp.array(2.)

jax_grad = jit(jgrad(jax_loss))

@jit
def jax_update_params(w, grad, lr):
    # Jax does not allow side effects
    # So have to return a new array
    return w - grad

# %%
# Jax have not implemented insertion yet
# and I do not think it will because of
# its functional and immutable arrays

jax_X = jnp.array(np.insert(X, 0, 1, axis=1))
jax_y = jnp.array(y)
jax_w = jnp.zeros(jax_X.shape[1])

# %%
n_iter = 10
history = jnp.empty(n_iter)
lr = jnp.array(1)
for i in range(n_iter):
    pred = jax_forward(jax_w, jax_X)
    
    loss = jax_loss(jax_w, jax_X, jax_y)
    history = jax.ops.index_update(history, i, loss)
    
    grad = jax_grad(jax_w, jax_X, jax_y)

    # For me gradients were divided by 1000
    # for this reason I choose learning rate = 1
    jax_w = jax_update_params(jax_w, grad, lr)

# %%
jax_w[1:]
# Out:
# DeviceArray([35.08756  , 84.64562  , 91.32015  , 91.69488  , 26.904041 ,
#              22.455051 , 43.793133 ,  1.8650593, 23.230263 , 64.99217  ],            dtype=float32)

# %%
coef
# Out:
# array([35.08755866, 84.64561755, 91.32015113, 91.69488078, 26.90404212,
#        22.45505084, 43.7931341 ,  1.86505838, 23.23026354, 64.99217604])

# %%
plt.plot(history);

# %% [markdown]
# ## MxNet

# %%
import mxnet
from mxnet import ndarray as mxarray
from mxnet import autograd as mxgrad

# %% [markdown]
# ### Functional

# %%
def mx_forward(w, X):
    return mxarray.dot(mx_X, mx_w)

def mx_loss(w, X, y):
    pred = mx_forward(w, X)
    return mxarray.mean(mxarray.square(pred - y)) / 2.0

def mx_update_params(w, grad, lr):
    return w - lr * grad

# %%
# Mx already uses numpy inserting
# so I used numpy 
mx_X = mxarray.array(np.insert(X, 0, 1, axis=1))
mx_y = mxarray.array(y)
mx_w = mxarray.zeros((mx_X.shape[1]))

# %%
n_iter = 10
history = mxarray.empty(n_iter)
for i in range(n_iter):
    mx_w.attach_grad()
    with mxgrad.record():
        pred = mx_forward(mx_w, mx_X)
        loss = mx_loss(mx_w, mx_X, mx_y)
    history[i] = loss.asscalar()
    loss.backward()
    mx_w = mx_update_params(mx_w, mx_w.grad, 1)

# %%
mx_w[1:].asnumpy()
# Out:
# array([35.08756 , 84.64562 , 91.32015 , 91.69488 , 26.904041, 22.455051,
#        43.793133,  1.865059, 23.230263, 64.99217 ], dtype=float32)

# %%
coef
# Out:
# array([35.08755866, 84.64561755, 91.32015113, 91.69488078, 26.90404212,
#        22.45505084, 43.7931341 ,  1.86505838, 23.23026354, 64.99217604])

# %%
plt.plot(history.asnumpy());

# %% [markdown]
# ### Object Oriented
